# %% [markdown]
# # Anatomy of a Figure

# %% [markdown]
# When working with matplotlib a common workflow for creating a figure would be:
#
# 1. import matplotlib
# 2. prepare our data
# 3. setup the plot
# 4. customize the plot
# 5. save and show the plot

# %%
import matplotlib.pyplot as plt

# %%
x = [2,6,10,15]
y = [33,76,80,110]

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(x,y);

# %%
ax.set(
    title="Our plot",
    xlabel="My fancy X axis",
    ylabel="Your fancy Y axis"
)
# Out:
# [Text(3.200000000000003, 0.5, 'Your fancy Y axis'),
#  Text(0.5, 3.200000000000003, 'My fancy X axis'),
#  Text(0.5, 1.0, 'Our plot')]

# %%
fig.savefig("_images/our_fancy_plot.png")

# %% [markdown]
# <img src="_images/our_fancy_plot.png" />

# %% [markdown]
# ## Figures with Numpy arrays

# %%
import numpy as np

# %%
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig, ax = plt.subplots()
ax.plot(x,x**2);

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.cos(x));

# %%
book_sales = {
    "1984": 12400,
    "Do Androids dream of Electric Sheep": 5400,
    "Neuromancer": 6000
}

# %%
fig, ax = plt.subplots()
ax.bar(
    book_sales.keys(),
    book_sales.values()
);
ax.set(
    title="Book Sales by Novel",
    xlabel="Novel Title",
    ylabel="# of Sales",
);

# %%
fig, ax = plt.subplots();
ax.barh(
    list(book_sales.keys()),
    list(book_sales.values())
)
ax.set(
    title="Book Sales by Novel",
    xlabel="Novel Title",
    ylabel="# of Sales",
);

# %%
normal_distribution = np.random.randn(1000)

fig, ax = plt.subplots()
ax.hist(normal_distribution);

# %% [markdown]
# ## Making multiple axis

# %%
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(
    nrows=2,
    ncols=2,
    figsize=(15,15)
)

ax1.plot(x,np.exp(x))
ax2.bar(x,np.tan(x))
ax3.scatter(x,np.sin(x))
ax4.hist(x);

# %%
fig, ax = plt.subplots(
    nrows=2,
    ncols=2,
    figsize=(15,15)
)

ax[0,0].plot(x,np.exp(x))
ax[0,1].bar(x,np.tan(x))
ax[1,0].scatter(x,np.sin(x))
ax[1,1].hist(x[:5]);
