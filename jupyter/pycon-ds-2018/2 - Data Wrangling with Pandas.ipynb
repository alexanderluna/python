# %% [markdown]
# # Data Wrangling with Pandas

# %% [markdown]
# We've seen how to get data with Python. Now let's do some stuff! From here on, we're going to mostly use the PyData stack rather than Python built-in functionality.
#
# Our objective in this section is to learn enough to clean the larger sample of Chicago Health Inspection data and get it ready for modeling.

# %% [markdown]
# ## Preliminaries: DataFrames

# %% [markdown]
# As mentioned, the core data structure in pandas is called a DataFrame. A DataFrame is a tabular data structure, holding many columns, similar to a spreadsheet.
#
# The **Key Features** are
#
# * Easy handling of **missing data**
# * **Size mutability**: columns can be inserted and deleted from DataFrames
# * Automatic and explicit **data alignment**: objects can be explicitly aligned to a set of labels, or the data can be aligned automatically
# * Powerful, flexible **group by functionality** to perform split-apply-combine operations on data sets
# * Intelligent label-based **slicing**, **fancy indexing**, and **subsetting** of large data sets
# * Intuitive **merging and joining** data sets
# * Flexible **reshaping and pivoting** of data sets
# * **Hierarchical labeling** of axes
# * Robust **IO tools** for loading data from flat files, Excel files, databases, and HDF5
# * **Time series functionality**:
#   * date range generation and frequency conversion
#   * moving window statistics
#   * moving window linear regressions
#   * date shifting and lagging, etc.

# %%
import pandas as pd

# %%
dta = pd.read_csv("data/health_inspection_chi.csv")

# %% [markdown]
# Pandas provides labelled **indices** to access rows and columns, should they have natural labels.

# %%
dta.index
# Out:
# RangeIndex(start=0, stop=25000, step=1)

# %%
dta.columns
# Out:
# Index(['address', 'aka_name', 'city', 'dba_name', 'facility_type',
#        'inspection_date', 'inspection_id', 'inspection_type', 'latitude',
#        'license_', 'location', 'longitude', 'results', 'risk', 'state',
#        'violations', 'zip'],
#       dtype='object')

# %% [markdown]
# For example, with this data set we have a natural unique identifier in the `inspection_id` column. We might wish to make this our index.

# %%
dta.head()
# Out:
#                       address                             aka_name     city  \
# 0            2804 N CLARK ST                  Wells Street Popcorn  CHICAGO
# 1         6744 N SHERIDAN RD                        RICE THAI CAFE  CHICAGO
# 2      160-164 E SUPERIOR ST                  GINO'S EAST PIZZERIA  CHICAGO
# 3       5844-5846 N BROADWAY   RAS DASHEN ETHIOPIAN RESTAURANT INC  CHICAGO
# 4  2352-2358 N MILWAUKEE AVE                             EAST ROOM  CHICAGO
#
#                               dba_name facility_type          inspection_date  \
# 0                 Wells Street Popcorn    Restaurant  2010-02-01T00:00:00.000
# 1                       RICE THAI CAFE    Restaurant  2015-08-21T00:00:00.000
# 2                 GINO'S EAST PIZZERIA    Restaurant  2015-07-28T00:00:00.000
# 3  RAS DASHEN ETHIOPIAN RESTAURANT INC    Restaurant  2017-01-04T00:00:00.000
# 4                            EAST ROOM        Liquor  2013-11-18T00:00:00.000
#
#    inspection_id                         inspection_type   latitude  \
# 0          68091                                 Canvass  41.932921
# 1        1482935                   Canvass Re-Inspection  42.004881
# 2        1447916  Suspected Food Poisoning Re-inspection  41.895863
# 3        1978933                                 Canvass  41.988326
# 4        1375515                   License Re-Inspection  41.923873
#
#     license_                                           location  longitude  \
# 0  1954774.0  {'type': 'Point', 'coordinates': [-87.64515454... -87.645155
# 1  2354674.0  {'type': 'Point', 'coordinates': [-87.66101071... -87.661011
# 2  1697132.0  {'type': 'Point', 'coordinates': [-87.62325304... -87.623253
# 3  1122395.0  {'type': 'Point', 'coordinates': [-87.66036036... -87.660360
# 4  2263696.0  {'type': 'Point', 'coordinates': [-87.69916285... -87.699163
#
#   results             risk state  \
# 0    Pass  Risk 2 (Medium)    IL
# 1    Pass    Risk 1 (High)    IL
# 2    Pass    Risk 1 (High)    IL
# 3    Fail    Risk 1 (High)    IL
# 4    Pass     Risk 3 (Low)    IL
#
#                                           violations      zip
# 0                                                NaN  60657.0
# 1  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60626.0
# 2  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60611.0
# 3  16. FOOD PROTECTED DURING STORAGE, PREPARATION...  60660.0
# 4                                                NaN  60647.0

# %%
dta = dta.set_index('inspection_id')

# %%
dta.index
# Out:
# Int64Index([  68091, 1482935, 1447916, 1978933, 1375515, 1434800, 1106632,
#             1981312, 1501267, 2129593,
#             ...
#             1387782,  679681, 1981776, 2009959, 1770545, 1482355, 1459253,
#             1751851, 2102939, 2009279],
#            dtype='int64', name='inspection_id', length=25000)

# %%
dta.head()
# Out:
#                                   address  \
# inspection_id
# 68091                    2804 N CLARK ST
# 1482935               6744 N SHERIDAN RD
# 1447916            160-164 E SUPERIOR ST
# 1978933             5844-5846 N BROADWAY
# 1375515        2352-2358 N MILWAUKEE AVE
#
#                                           aka_name     city  \
# inspection_id
# 68091                         Wells Street Popcorn  CHICAGO
# 1482935                             RICE THAI CAFE  CHICAGO
# 1447916                       GINO'S EAST PIZZERIA  CHICAGO
# 1978933        RAS DASHEN ETHIOPIAN RESTAURANT INC  CHICAGO
# 1375515                                  EAST ROOM  CHICAGO
#
#                                           dba_name facility_type  \
# inspection_id
# 68091                         Wells Street Popcorn    Restaurant
# 1482935                             RICE THAI CAFE    Restaurant
# 1447916                       GINO'S EAST PIZZERIA    Restaurant
# 1978933        RAS DASHEN ETHIOPIAN RESTAURANT INC    Restaurant
# 1375515                                  EAST ROOM        Liquor
#
#                        inspection_date  \
# inspection_id
# 68091          2010-02-01T00:00:00.000
# 1482935        2015-08-21T00:00:00.000
# 1447916        2015-07-28T00:00:00.000
# 1978933        2017-01-04T00:00:00.000
# 1375515        2013-11-18T00:00:00.000
#
#                                       inspection_type   latitude   license_  \
# inspection_id
# 68091                                         Canvass  41.932921  1954774.0
# 1482935                         Canvass Re-Inspection  42.004881  2354674.0
# 1447916        Suspected Food Poisoning Re-inspection  41.895863  1697132.0
# 1978933                                       Canvass  41.988326  1122395.0
# 1375515                         License Re-Inspection  41.923873  2263696.0
#
#                                                         location  longitude  \
# inspection_id
# 68091          {'type': 'Point', 'coordinates': [-87.64515454... -87.645155
# 1482935        {'type': 'Point', 'coordinates': [-87.66101071... -87.661011
# 1447916        {'type': 'Point', 'coordinates': [-87.62325304... -87.623253
# 1978933        {'type': 'Point', 'coordinates': [-87.66036036... -87.660360
# 1375515        {'type': 'Point', 'coordinates': [-87.69916285... -87.699163
#
#               results             risk state  \
# inspection_id
# 68091            Pass  Risk 2 (Medium)    IL
# 1482935          Pass    Risk 1 (High)    IL
# 1447916          Pass    Risk 1 (High)    IL
# 1978933          Fail    Risk 1 (High)    IL
# 1375515          Pass     Risk 3 (Low)    IL
#
#                                                       violations      zip
# inspection_id
# 68091                                                        NaN  60657.0
# 1482935        32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60626.0
# 1447916        32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60611.0
# 1978933        16. FOOD PROTECTED DURING STORAGE, PREPARATION...  60660.0
# 1375515                                                      NaN  60647.0

# %% [markdown]
# ## Indexing

# %% [markdown]
# To look at a column from a DataFrame, you can either use attribute lookup.

# %%
dta.address
# Out:
# inspection_id
# 68091                         2804 N CLARK ST
# 1482935                    6744 N SHERIDAN RD
# 1447916                 160-164 E SUPERIOR ST
# 1978933                  5844-5846 N BROADWAY
# 1375515             2352-2358 N MILWAUKEE AVE
# 1434800                     4140 W Addison ST
# 1106632                    5657 N LINCOLN AVE
# 1981312                     1234 N HALSTED ST
# 1501267                           3700 S LOWE
# 2129593                    2506 N LARAMIE AVE
# 565226           131 N CLINTON ST BLDG BOOTH26
# 2102944                    3450 N LINCOLN AVE
# 1482500                       4445 N BROADWAY
# 1684292                       200 W MONROE ST
# 1546447                 1431 N NORTH PARK AVE
# 2169836                       2935 N BROADWAY
# 1229384                  1366 N MILWAUKEE AVE
# 2072068                     11601 W TOUHY AVE
# 1227664                        3956 W 63RD ST
# 2088450                    1424 W CHICAGO AVE
# 1202567                        3350 W 47th ST
# 2049483                        2334 E 75TH ST
# 233722                       3121 W CERMAK RD
# 2098892                 5467 S UNIVERSITY AVE
# 2104803                       3508 N BROADWAY
# 1198862                     2256 N ELSTON AVE
# 1154350                         317 E 51ST ST
# 284278                3813-3815 W CHICAGO AVE
# 1473477                     3059 S PULASKI RD
# 88620                      6059 N LINCOLN AVE
#                           ...
# 537512                         401 E 111TH ST
# 1092801                    3450 N LINCOLN AVE
# 1516702                     6190 S ARCHER AVE
# 2130187                     4046 N LEAVITT ST
# 614248                         535 S STATE ST
# 1575899    3800 S DR MARTIN LUTHER KING JR DR
# 2129554                   1025 W VAN BUREN ST
# 250306                     1814 W CHICAGO AVE
# 1151310                     5833 S KEDZIE AVE
# 1591458                     205 W Randolph ST
# 1633153                       4220 N Richmond
# 417333                          727 E 87TH ST
# 2129830                        6452 W 63RD ST
# 1300914                 1541 W BRYN  MAWR AVE
# 158246                       2130 W CERMAK RD
# 1386114               6560 S STONY ISLAND AVE
# 1981970                     11601 W TOUHY AVE
# 2049937                    10001 S Pulaski RD
# 2070153                    5613 W CORCORAN PL
# 1236222                    5806 N WESTERN AVE
# 1387782              8200 S COTTAGE GROVE AVE
# 679681                      2703 N HALSTED ST
# 1981776                          7350 S Evans
# 2009959                       1442 W 103RD ST
# 1770545                     731 N DEARBORN ST
# 1482355                  4400-4404 N CLARK ST
# 1459253                3709-3713 N HARLEM AVE
# 1751851                       1816 N CLARK ST
# 2102939                        1501 E 53RD ST
# 2009279                      2154 W DEVON AVE
# Name: address, Length: 25000, dtype: object

# %% [markdown]
# Or you can use the **getitem** syntax that relies on square brackets `[]`, which is familiar from dealing with dictionaries (uses `__getitem__`).

# %%
dta['address']

# %% [markdown]
# These two operations return pandas **Series** objects. **Series** are like single-column DataFrames. If you want to preserve the DataFrame type, index the DataFrame with a list.

# %%
dta[['address']]
# Out:
#                                            address
# inspection_id
# 68091                             2804 N CLARK ST
# 1482935                        6744 N SHERIDAN RD
# 1447916                     160-164 E SUPERIOR ST
# 1978933                      5844-5846 N BROADWAY
# 1375515                 2352-2358 N MILWAUKEE AVE
# 1434800                         4140 W Addison ST
# 1106632                        5657 N LINCOLN AVE
# 1981312                         1234 N HALSTED ST
# 1501267                               3700 S LOWE
# 2129593                        2506 N LARAMIE AVE
# 565226               131 N CLINTON ST BLDG BOOTH26
# 2102944                        3450 N LINCOLN AVE
# 1482500                           4445 N BROADWAY
# 1684292                           200 W MONROE ST
# 1546447                     1431 N NORTH PARK AVE
# 2169836                           2935 N BROADWAY
# 1229384                      1366 N MILWAUKEE AVE
# 2072068                         11601 W TOUHY AVE
# 1227664                            3956 W 63RD ST
# 2088450                        1424 W CHICAGO AVE
# 1202567                            3350 W 47th ST
# 2049483                            2334 E 75TH ST
# 233722                           3121 W CERMAK RD
# 2098892                     5467 S UNIVERSITY AVE
# 2104803                           3508 N BROADWAY
# 1198862                         2256 N ELSTON AVE
# 1154350                             317 E 51ST ST
# 284278                    3813-3815 W CHICAGO AVE
# 1473477                         3059 S PULASKI RD
# 88620                          6059 N LINCOLN AVE
# ...                                            ...
# 537512                             401 E 111TH ST
# 1092801                        3450 N LINCOLN AVE
# 1516702                         6190 S ARCHER AVE
# 2130187                         4046 N LEAVITT ST
# 614248                             535 S STATE ST
# 1575899        3800 S DR MARTIN LUTHER KING JR DR
# 2129554                       1025 W VAN BUREN ST
# 250306                         1814 W CHICAGO AVE
# 1151310                         5833 S KEDZIE AVE
# 1591458                         205 W Randolph ST
# 1633153                           4220 N Richmond
# 417333                              727 E 87TH ST
# 2129830                            6452 W 63RD ST
# 1300914                     1541 W BRYN  MAWR AVE
# 158246                           2130 W CERMAK RD
# 1386114                   6560 S STONY ISLAND AVE
# 1981970                         11601 W TOUHY AVE
# 2049937                        10001 S Pulaski RD
# 2070153                        5613 W CORCORAN PL
# 1236222                        5806 N WESTERN AVE
# 1387782                  8200 S COTTAGE GROVE AVE
# 679681                          2703 N HALSTED ST
# 1981776                              7350 S Evans
# 2009959                           1442 W 103RD ST
# 1770545                         731 N DEARBORN ST
# 1482355                      4400-4404 N CLARK ST
# 1459253                    3709-3713 N HARLEM AVE
# 1751851                           1816 N CLARK ST
# 2102939                            1501 E 53RD ST
# 2009279                          2154 W DEVON AVE
#
# [25000 rows x 1 columns]

# %% [markdown]
# You can use this syntax to pull out multiple columns.

# %%
dta[['address', 'inspection_date']]
# Out:
#                                            address          inspection_date
# inspection_id
# 68091                             2804 N CLARK ST   2010-02-01T00:00:00.000
# 158246                           2130 W CERMAK RD   2010-01-06T00:00:00.000
# 1386114                   6560 S STONY ISLAND AVE   2015-05-05T00:00:00.000
# 1981970                         11601 W TOUHY AVE   2017-01-24T00:00:00.000
# 2049937                        10001 S Pulaski RD   2017-05-08T00:00:00.000
# 2070153                        5613 W CORCORAN PL   2017-07-20T00:00:00.000
# 1236222                        5806 N WESTERN AVE   2014-03-10T00:00:00.000
# 1387782                  8200 S COTTAGE GROVE AVE   2014-12-08T00:00:00.000
# 679681                          2703 N HALSTED ST   2012-03-14T00:00:00.000
# 1981776                              7350 S Evans   2017-01-20T00:00:00.000
# 2009959                           1442 W 103RD ST   2017-04-06T00:00:00.000
# 1770545                         731 N DEARBORN ST   2016-05-10T00:00:00.000
# 1482355                      4400-4404 N CLARK ST   2014-08-28T00:00:00.000
# 1459253                    3709-3713 N HARLEM AVE   2014-04-29T00:00:00.000
# 1751851                           1816 N CLARK ST   2016-04-12T00:00:00.000
# 2102939                            1501 E 53RD ST   2017-10-31T00:00:00.000
# 2009279                          2154 W DEVON AVE   2017-03-24T00:00:00.000
#
# [25000 rows x 2 columns]

# %% [markdown]
# You can index the rows, by using the **loc** and **iloc** accessors.
#
# `loc` does *label-based* indexing.

# %%
dta.loc[[1965287, 1329698]]
# Out:
# ---------------------------------------------------------
# KeyError                Traceback (most recent call last)
# <ipython-input-36-c5f7bce4584c> in <module>()
# ----> 1 dta.loc[[1965287, 1329698]]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
# -> 1901                 return self._getitem_iterable(key, axis=axis)
#    1902
#    1903             # nested tuple slicing
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1141             if labels.is_unique and Index(keyarr).is_unique:
#    1142                 indexer = ax.get_indexer_for(key)
# -> 1143                 self._validate_read_indexer(key, indexer, axis)
#    1144
#    1145                 d = {axis: [ax.reindex(keyarr)[0], indexer]}
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1204                 raise KeyError(
#    1205                     u"None of [{key}] are in the [{axis}]".format(
# -> 1206                         key=key, axis=self.obj._get_axis_name(axis)))
#    1207
#    1208             # we skip the warning on Categorical/Interval
#
# KeyError: 'None of [[1965287, 1329698]] are in the [index]'

# %% [markdown]
# `iloc` on the other hand provides *integer-based* indexing. We can pass a list of rows integers.

# %%
dta.iloc[[0, 2]]
# Out:
#                   address              aka_name     city  \
# 0        2804 N CLARK ST   Wells Street Popcorn  CHICAGO
# 2  160-164 E SUPERIOR ST   GINO'S EAST PIZZERIA  CHICAGO
#
#                dba_name facility_type          inspection_date  inspection_id  \
# 0  Wells Street Popcorn    Restaurant  2010-02-01T00:00:00.000          68091
# 2  GINO'S EAST PIZZERIA    Restaurant  2015-07-28T00:00:00.000        1447916
#
#                           inspection_type   latitude   license_  \
# 0                                 Canvass  41.932921  1954774.0
# 2  Suspected Food Poisoning Re-inspection  41.895863  1697132.0
#
#                                             location  longitude results  \
# 0  {'type': 'Point', 'coordinates': [-87.64515454... -87.645155    Pass
# 2  {'type': 'Point', 'coordinates': [-87.62325304... -87.623253    Pass
#
#               risk state                                         violations  \
# 0  Risk 2 (Medium)    IL                                                NaN
# 2    Risk 1 (High)    IL  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
#
#        zip
# 0  60657.0
# 2  60611.0

# %% [markdown]
# Both support the Python **slice notation** (`start:stop:step`). This can be really powerful.

# %%
dta.iloc[:5]
# Out:
#                       address                             aka_name     city  \
# 0            2804 N CLARK ST                  Wells Street Popcorn  CHICAGO
# 1         6744 N SHERIDAN RD                        RICE THAI CAFE  CHICAGO
# 2      160-164 E SUPERIOR ST                  GINO'S EAST PIZZERIA  CHICAGO
# 3       5844-5846 N BROADWAY   RAS DASHEN ETHIOPIAN RESTAURANT INC  CHICAGO
# 4  2352-2358 N MILWAUKEE AVE                             EAST ROOM  CHICAGO
#
#                               dba_name facility_type          inspection_date  \
# 0                 Wells Street Popcorn    Restaurant  2010-02-01T00:00:00.000
# 1                       RICE THAI CAFE    Restaurant  2015-08-21T00:00:00.000
# 2                 GINO'S EAST PIZZERIA    Restaurant  2015-07-28T00:00:00.000
# 3  RAS DASHEN ETHIOPIAN RESTAURANT INC    Restaurant  2017-01-04T00:00:00.000
# 4                            EAST ROOM        Liquor  2013-11-18T00:00:00.000
#
#    inspection_id                         inspection_type   latitude  \
# 0          68091                                 Canvass  41.932921
# 1        1482935                   Canvass Re-Inspection  42.004881
# 2        1447916  Suspected Food Poisoning Re-inspection  41.895863
# 3        1978933                                 Canvass  41.988326
# 4        1375515                   License Re-Inspection  41.923873
#
#     license_                                           location  longitude  \
# 0  1954774.0  {'type': 'Point', 'coordinates': [-87.64515454... -87.645155
# 1  2354674.0  {'type': 'Point', 'coordinates': [-87.66101071... -87.661011
# 2  1697132.0  {'type': 'Point', 'coordinates': [-87.62325304... -87.623253
# 3  1122395.0  {'type': 'Point', 'coordinates': [-87.66036036... -87.660360
# 4  2263696.0  {'type': 'Point', 'coordinates': [-87.69916285... -87.699163
#
#   results             risk state  \
# 0    Pass  Risk 2 (Medium)    IL
# 1    Pass    Risk 1 (High)    IL
# 2    Pass    Risk 1 (High)    IL
# 3    Fail    Risk 1 (High)    IL
# 4    Pass     Risk 3 (Low)    IL
#
#                                           violations      zip
# 0                                                NaN  60657.0
# 1  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60626.0
# 2  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60611.0
# 3  16. FOOD PROTECTED DURING STORAGE, PREPARATION...  60660.0
# 4                                                NaN  60647.0

# %%
dta.loc[:1335320]
# Out:
#                                    address  \
# 0                         2804 N CLARK ST
# 1                      6744 N SHERIDAN RD
# 2                   160-164 E SUPERIOR ST
# 3                    5844-5846 N BROADWAY
# 4               2352-2358 N MILWAUKEE AVE
# 5                       4140 W Addison ST
# 6                      5657 N LINCOLN AVE
# 7                       1234 N HALSTED ST
# 8                             3700 S LOWE
# 9                      2506 N LARAMIE AVE
# 10           131 N CLINTON ST BLDG BOOTH26
# 11                     3450 N LINCOLN AVE
# 12                        4445 N BROADWAY
# 13                        200 W MONROE ST
# 14                  1431 N NORTH PARK AVE
# 15                        2935 N BROADWAY
# 16                   1366 N MILWAUKEE AVE
# 17                      11601 W TOUHY AVE
# 26                    RED APPLE FOOD & LIQUOR INC
# 27                        SUGA RAY'S SPORTS GRILL
# 28                   PIEZANO'S PIZZA & GRINDER CO
# 29                                   PANERA BREAD
# ...                                           ...
# 24970        HAPPY HOLIDAY NURSERY & KINDERGARTEN
# 24971                       FERNANDO'S RESTAURANT
# 24972                               WINGSTOP #587
# 24973              JOHN COONLEY ELEMENTARY SCHOOL
# 24974                            7-ELEVEN #33496C
# 24975                             PIONEER GARDENS
# 24976                         SHORT STUFF CHICAGO
# 24977                                  TECALITLAN
# 24978                          CHINESE #1 KITCHEN
# 24979                     P & H CONVENIENCE STORE
# 24980            Newton Bateman Elementary School
# 24981                     ST REST COUNTRY KITCHEN
# 24982                 WING WAH CHINESE RESTAURANT
# 24983                             LITTLE BAD WOLF
# 24984                         LAS TRES CAMPANITAS
# 24985                                  MCDONALD'S
# 24986                           AMERICAN AIRLINES
# 24987                    BROTHER RICE HIGH SCHOOL
# 24988  LITTLE LEADERS OF TOMORROW DAY CARE CENTER
# 24989                              D-4 RESTAURANT
# 24990                             D AND Y GROCERY
# 24991                                MAYAN PALACE
# 24992                  HENRY O. TANNER ELEMENTARY
# 24993                                 IRIE ISLAND
# 24994                             BELLA LUNA CAFE
# 24995                         ANNA MARIA PASTERIA
# 24996                                       YUMMY
# 24997                               HOTEL LINCOLN
# 24998                                 PIZZA CAPRI
# 24999                           VILLA PALERMO INC
#
#                          facility_type          inspection_date  \
# 0                           Restaurant  2010-02-01T00:00:00.000
# 1                           Restaurant  2015-08-21T00:00:00.000
# 2                           Restaurant  2015-07-28T00:00:00.000
# 3                           Restaurant  2017-01-04T00:00:00.000
# 4                               Liquor  2013-11-18T00:00:00.000
# 5                               School  2014-04-14T00:00:00.000
# 6                           Restaurant  2013-06-14T00:00:00.000
# 7                           Restaurant  2017-01-11T00:00:00.000
# 8                               School  2014-10-28T00:00:00.000
# 9                               Bakery  2017-12-21T00:00:00.000
# 10                          Restaurant  2011-02-23T00:00:00.000
# 11                          Restaurant  2017-10-31T00:00:00.000
# 12                       Grocery Store  2014-11-04T00:00:00.000
# 13                          Restaurant  2016-03-28T00:00:00.000
# 14                              School  2015-05-27T00:00:00.000
# 15                          Restaurant  2018-05-16T00:00:00.000
# 16                              TAVERN  2012-06-05T00:00:00.000
# 17                          Restaurant  2017-08-08T00:00:00.000
# 18                              Bakery  2012-11-14T00:00:00.000
# 19                          Restaurant  2017-09-19T00:00:00.000
# 20                          Restaurant  2012-12-19T00:00:00.000
# 21     Daycare Above and Under 2 Years  2017-04-28T00:00:00.000
# 22                                 NaN  2010-05-11T00:00:00.000
# 23        Children's Services Facility  2017-10-16T00:00:00.000
# 24                          Restaurant  2017-11-16T00:00:00.000
# 25                              Bakery  2013-05-15T00:00:00.000
# 26                       Grocery Store  2012-05-30T00:00:00.000
# 27                          Restaurant  2010-08-12T00:00:00.000
# 28                          Restaurant  2014-06-09T00:00:00.000
# 29                          Restaurant  2010-12-09T00:00:00.000
# ...                                ...                      ...
# 25     1888258.0  {'type': 'Point', 'coordinates': [-87.67400666...
# 26       10894.0  {'type': 'Point', 'coordinates': [-87.61868295...
# 27     1922230.0  {'type': 'Point', 'coordinates': [-87.72179977...
# 28       18272.0  {'type': 'Point', 'coordinates': [-87.72420568...
# 29     1475890.0  {'type': 'Point', 'coordinates': [-87.70963133...
# ...          ...                                                ...
# 24970  1477908.0  {'type': 'Point', 'coordinates': [-87.61331405...
# 24971    36911.0  {'type': 'Point', 'coordinates': [-87.67225084...
# 24972  2134060.0  {'type': 'Point', 'coordinates': [-87.77414737...
# 24973    22821.0  {'type': 'Point', 'coordinates': [-87.68380194...
# 24974  1970111.0  {'type': 'Point', 'coordinates': [-87.62747463...
# 24975  1677537.0  {'type': 'Point', 'coordinates': [-87.61717841...
# 24976  2569352.0  {'type': 'Point', 'coordinates': [-87.65294630...
# 24977     7246.0  {'type': 'Point', 'coordinates': [-87.67282790...
# 24978  2120075.0  {'type': 'Point', 'coordinates': [-87.70322295...
# 24979  2196521.0  {'type': 'Point', 'coordinates': [-87.63407990...
# 24980    22171.0  {'type': 'Point', 'coordinates': [-87.70218806...
# 24981    11696.0  {'type': 'Point', 'coordinates': [-87.60618644...
# 24982  1879298.0  {'type': 'Point', 'coordinates': [-87.78339851...
# 24983  2088978.0  {'type': 'Point', 'coordinates': [-87.66910121...
# 24984  2013269.0  {'type': 'Point', 'coordinates': [-87.67955938...
# 24985  1943516.0  {'type': 'Point', 'coordinates': [-87.58643662...
# 24986  2284294.0  {'type': 'Point', 'coordinates': [-87.91442843...
# 24987  1980784.0  {'type': 'Point', 'coordinates': [-87.72093947...
# 24988  2216004.0  {'type': 'Point', 'coordinates': [-87.76568360...
# 24989  2060730.0  {'type': 'Point', 'coordinates': [-87.68970509...
# 24990  1477137.0  {'type': 'Point', 'coordinates': [-87.60522820...
# 24991  1300822.0  {'type': 'Point', 'coordinates': [-87.64882688...
# 24992    26281.0  {'type': 'Point', 'coordinates': [-87.60682834...
# 24993  2271525.0  {'type': 'Point', 'coordinates': [-87.65894640...
# 24994    86092.0  {'type': 'Point', 'coordinates': [-87.62961054...
# 24995  1513905.0  {'type': 'Point', 'coordinates': [-87.66612372...
# 24996  2184668.0  {'type': 'Point', 'coordinates': [-87.80693252...
# 24997  2442928.0  {'type': 'Point', 'coordinates': [-87.63429326...
# 24998    39084.0  {'type': 'Point', 'coordinates': [-87.58904625...
# 24999     1470.0  {'type': 'Point', 'coordinates': [-87.68478485...
#
#        longitude             results             risk state  \
# 0     -87.645155                Pass  Risk 2 (Medium)    IL
# 1     -87.661011                Pass    Risk 1 (High)    IL
# 2     -87.623253                Pass    Risk 1 (High)    IL
# 3     -87.660360                Fail    Risk 1 (High)    IL
# 4     -87.699163                Pass     Risk 3 (Low)    IL
# 5     -87.730738                Pass    Risk 1 (High)    IL
# 6     -87.697050                Pass    Risk 1 (High)    IL
# 7     -87.648267                Pass    Risk 1 (High)    IL
. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60626.0
# 2      32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60611.0
# 3      16. FOOD PROTECTED DURING STORAGE, PREPARATION...  60660.0
# 4                                                    NaN  60647.0
# 5      33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  60641.0
# 6      32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60659.0
# 7      33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  60642.0
# 8      33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  60609.0
# 9                                                    NaN  60639.0
# 10                                                   NaN  60661.0
# 11     13. NO EVIDENCE OF RODENT OR INSECT INFESTATIO...  60657.0
# 12     14. PREVIOUS SERIOUS VIOLATION CORRECTED, 7-42...  60640.0
# 13                                                   NaN  60606.0
# 14                                                   NaN  60610.0
# 15     36. LIGHTING: REQUIRED MINIMUM FOOT-CANDLES OF...  60657.0
# 16     12. HAND WASHING FACILITIES: WITH SOAP AND SAN...  60642.0
# 17                                                   NaN  60666.0
# 18     33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  60629.0
# 19                                                   NaN  60642.0
# 20     30. FOOD IN ORIGINAL CONTAINER, PROPERLY LABEL...  60632.0
# 21     34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  60649.0
# 22                                                   NaN  60623.0
# 23     38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...  60615.0
# 24     30. FOOD IN ORIGINAL CONTAINER, PROPERLY LABEL...  60657.0
# 25     32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60614.0
# 26     12. HAND WASHING FACILITIES: WITH SOAP AND SAN...  60615.0
# 27                                                   NaN  60651.0
# 28     34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  60623.0
# 29     18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  60659.0
# ...                                                  ...      ...
# 24970  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  60628.0
# 24971  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60657.0
# 24972  21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTE...  60638.0
# 24973  38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...  60618.0
# 24974  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  60605.0
# 24975  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  60653.0
# 24976  11. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, D...  60607.0
# 24977  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  60622.0
# 24978  31. CLEAN MULTI-USE UTENSILS AND SINGLE SERVIC...  60629.0
# 24979  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  60606.0
# 24980  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  60618.0
# 24981  30. FOOD IN ORIGINAL CONTAINER, PROPERLY LABEL...  60619.0
# 24982  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  60638.0
# 24983                                                NaN  60660.0
# 24984  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  60608.0
# 24985  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  60637.0
# 24986  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  60666.0
# 24987  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  60655.0
# 24988  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60644.0
# 24989  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  60659.0
# 24990  3. POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATUR...  60619.0
# 24991                                                NaN  60614.0
# 24992  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  60619.0
# 24993  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  60643.0
# 24994  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60610.0
# 24995  16. FOOD PROTECTED DURING STORAGE, PREPARATION...  60640.0
# 24996  30. FOOD IN ORIGINAL CONTAINER, PROPERLY LABEL...  60634.0
# 24997  26. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, P...  60614.0
# 24998  30. FOOD IN ORIGINAL CONTAINER, PROPERLY LABEL...  60615.0
# 24999  19. OUTSIDE GARBAGE WASTE GREASE AND STORAGE A...  60659.0
#
# [25000 rows x 17 columns]

# %% [markdown]
# Note that these inspection ids are *not* sorted, yet we can still use slice notation.

# %% [markdown]
# Of course, we can also combine row and index labeling.

# %%
dta.iloc[:5, [0, 5]]
# Out:
#                       address          inspection_date
# 0            2804 N CLARK ST   2010-02-01T00:00:00.000
# 1         6744 N SHERIDAN RD   2015-08-21T00:00:00.000
# 2      160-164 E SUPERIOR ST   2015-07-28T00:00:00.000
# 3       5844-5846 N BROADWAY   2017-01-04T00:00:00.000
# 4  2352-2358 N MILWAUKEE AVE   2013-11-18T00:00:00.000

# %%
dta.loc[:68091, ["address", "inspection_date"]]
# Out:
#                                    address          inspection_date
# 0                         2804 N CLARK ST   2010-02-01T00:00:00.000
# 1                      6744 N SHERIDAN RD   2015-08-21T00:00:00.000
# 2                   160-164 E SUPERIOR ST   2015-07-28T00:00:00.000
# 24988                  5613 W CORCORAN PL   2017-07-20T00:00:00.000
# 24989                  5806 N WESTERN AVE   2014-03-10T00:00:00.000
# 24990            8200 S COTTAGE GROVE AVE   2014-12-08T00:00:00.000
# 24991                   2703 N HALSTED ST   2012-03-14T00:00:00.000
# 24992                        7350 S Evans   2017-01-20T00:00:00.000
# 24993                     1442 W 103RD ST   2017-04-06T00:00:00.000
# 24994                   731 N DEARBORN ST   2016-05-10T00:00:00.000
# 24995                4400-4404 N CLARK ST   2014-08-28T00:00:00.000
# 24996              3709-3713 N HARLEM AVE   2014-04-29T00:00:00.000
# 24997                     1816 N CLARK ST   2016-04-12T00:00:00.000
# 24998                      1501 E 53RD ST   2017-10-31T00:00:00.000
# 24999                    2154 W DEVON AVE   2017-03-24T00:00:00.000
#
# [25000 rows x 2 columns]

# %% [markdown]
# ## Cleaning Data for Types

# %% [markdown]
# So far, we've explicitly made an index. We may next want to convert to the dates to datetime types. Here we'll use the **apply** function to apply a function to each row of a Series.

# %%
dta.inspection_date = dta.inspection_date.apply(pd.to_datetime)

# %%
dta.inspection_date

# %% [markdown]
# Now let's cast zip code from a float to a string. Some zip codes can start with 0 (not in Chicago), and we need to account for that.

# %%
import numpy as np


def float_to_zip(zip_code):
    if np.isnan(zip_code):
        return np.nan
    
    # 0 makes sure to left-pad with zero
    # zip codes have 5 digits
    # .0 means, we don't want anything after the decimal
    # f is for float
    zip_code = "{:05.0f}".format(zip_code)
    return zip_code

# %% [markdown]
# Here we use Python's **string formatting** facilities to convert from a numeric type to a string. Some of the zip codes are empty strings in the file. Pandas uses numpy's `NaN` to indicate missingness, so we'll return it here.

# %%
dta.zip = dta.zip.apply(float_to_zip)

# %%
dta.head()
# Out:
#                       address                             aka_name     city  \
# 0            2804 N CLARK ST                  Wells Street Popcorn  CHICAGO
# 1         6744 N SHERIDAN RD                        RICE THAI CAFE  CHICAGO
# 2      160-164 E SUPERIOR ST                  GINO'S EAST PIZZERIA  CHICAGO
# 3       5844-5846 N BROADWAY   RAS DASHEN ETHIOPIAN RESTAURANT INC  CHICAGO
# 4  2352-2358 N MILWAUKEE AVE                             EAST ROOM  CHICAGO
#
#                               dba_name facility_type          inspection_date  \
# 0                 Wells Street Popcorn    Restaurant  2010-02-01T00:00:00.000
# 1                       RICE THAI CAFE    Restaurant  2015-08-21T00:00:00.000
# 2                 GINO'S EAST PIZZERIA    Restaurant  2015-07-28T00:00:00.000
# 3  RAS DASHEN ETHIOPIAN RESTAURANT INC    Restaurant  2017-01-04T00:00:00.000
# 4                            EAST ROOM        Liquor  2013-11-18T00:00:00.000
#
#    inspection_id                         inspection_type   latitude  \
# 0          68091                                 Canvass  41.932921
# 1        1482935                   Canvass Re-Inspection  42.004881
# 2        1447916  Suspected Food Poisoning Re-inspection  41.895863
# 3        1978933                                 Canvass  41.988326
# 4        1375515                   License Re-Inspection  41.923873
#
#     license_                                           location  longitude  \
# 0  1954774.0  {'type': 'Point', 'coordinates': [-87.64515454... -87.645155
# 1  2354674.0  {'type': 'Point', 'coordinates': [-87.66101071... -87.661011
# 2  1697132.0  {'type': 'Point', 'coordinates': [-87.62325304... -87.623253
# 3  1122395.0  {'type': 'Point', 'coordinates': [-87.66036036... -87.660360
# 4  2263696.0  {'type': 'Point', 'coordinates': [-87.69916285... -87.699163
#
#   results             risk state  \
# 0    Pass  Risk 2 (Medium)    IL
# 1    Pass    Risk 1 (High)    IL
# 2    Pass    Risk 1 (High)    IL
# 3    Fail    Risk 1 (High)    IL
# 4    Pass     Risk 3 (Low)    IL
#
#                                           violations    zip
# 0                                                NaN  60657
# 1  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60626
# 2  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60611
# 3  16. FOOD PROTECTED DURING STORAGE, PREPARATION...  60660
# 4                                                NaN  60647

# %% [markdown]
# DataFrames have a `dtypes` attribute for checking the data types. Pandas relies on NumPy's dtypes objects. Here we see that the `object` dtype is used to hold strings. This for technical reasons.

# %%
dta.dtypes[['inspection_date', 'zip']]
# Out:
# inspection_date    object
# zip                object
# dtype: object

# %% [markdown]
# We can also convert variables' types, using `astype`. Here, we'll explicitly cast to pandas Categorical type, which is the only non-native numpy type.

# %%
dta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 17 columns):
# address            25000 non-null object
# aka_name           24731 non-null object
# city               24978 non-null object
# dba_name           25000 non-null object
# facility_type      24565 non-null object
# inspection_date    25000 non-null object
# inspection_id      25000 non-null int64
# inspection_type    25000 non-null object
# latitude           24822 non-null float64
# license_           24999 non-null float64
# location           24822 non-null object
# longitude          24822 non-null float64
# results            25000 non-null object
# risk               24991 non-null object
# state              24995 non-null object
# violations         19538 non-null object
# zip                24991 non-null object
# dtypes: float64(3), int64(1), object(13)
# memory usage: 3.2+ MB

# %%
dta.results = dta.results.astype('category')
dta.risk = dta.risk.astype('category')
dta.inspection_type = dta.inspection_type.astype('category')
dta.facility_type = dta.facility_type.astype('category')

# %% [markdown]
# If we only select the categorical types, we can see some categorical variables descriptions.

# %% [markdown]
# We can use the `select_dtypes` method to pull out a DataFrame with only the asked for types.

# %%
dta.select_dtypes(['category'])
# Out:
#                          facility_type  \
# 0                           Restaurant
# 1                           Restaurant
# 2                           Restaurant
# 3                           Restaurant
# 4                               Liquor
# 5                               School
# 6                           Restaurant
# 7                           Restaurant
# 8                               School
# 9                               Bakery
# 10                          Restaurant
# 11                          Restaurant
# 12                       Grocery Store
# 13                          Restaurant
# 14                              School
# 15                          Restaurant
# 16                              TAVERN
# 17                          Restaurant
# 18                              Bakery
# 19                          Restaurant
# 20                          Restaurant
# 21     Daycare Above and Under 2 Years
# 22                                 NaN
# 23        Children's Services Facility
# 24                          Restaurant
# 25                              Bakery
# 26                       Grocery Store
# 27                          Restaurant
# 28                          Restaurant
# 29                          Restaurant
# ...                                ...
# 24970  Daycare Above and Under 2 Years
# 24971                       Restaurant
# 24972                       Restaurant
# 24973                           School
# 24974                convenience store
# 24975                       Restaurant
# 24976     Children's Services Facility
# 24977                       Restaurant
# 24978                       Restaurant
# 24979                    Grocery Store
# 24980                           School
# 24981                       Restaurant
# 24982                       Restaurant
# 24983                       Restaurant
# 24984                       Restaurant
# 24985                       Restaurant
# 24986                       Restaurant
# 24987                           School
# 24988     Children's Services Facility
# 24989                       Restaurant
# 24990                    Grocery Store
# 24991                       Restaurant
# 24992                           School
# 24993                       Restaurant
# 24994                       Restaurant
# 24995                       Restaurant
# 24996                       Restaurant
# 24997                       Restaurant
# 24998                       Restaurant
# 24999                       Restaurant
#
#                               inspection_type             results  \
# 0                                     Canvass                Pass
# 1                       Canvass Re-Inspection                Pass
# 2      Suspected Food Poisoning Re-inspection                Pass
# 3                                     Canvass                Fail
# 4                       License Re-Inspection                Pass
# 5                                     Canvass                Pass
# 6                       Canvass Re-Inspection                Pass
# 7                                     Canvass                Pass
# 8                                     Canvass                Pass
# 9                                     Canvass     Out of Business
# 10                                    Canvass     Out of Business
# 11                                  Complaint                Fail
# 12                      Canvass Re-Inspection                Fail
# 13                      Canvass Re-Inspection                Pass
# 14                                    Canvass                Pass
# 15                      Canvass Re-Inspection                Pass
# 16                                    License                Fail
# 17                      License Re-Inspection                Pass
# 18                      Canvass Re-Inspection                Pass
# 19                                    Canvass            No Entry
# 20                                    Canvass                Pass
# 21                                    Canvass                Pass
# 22                                    Canvass                Fail
# 23                      Canvass Re-Inspection                Pass
# 24                      Canvass Re-Inspection                Pass
# 25                      Canvass Re-Inspection                Pass
# 26                                  Complaint                Fail
# 27                                    Canvass     Out of Business
# 28                                    Canvass                Pass
# 29                                    Canvass                Fail
# ...                                       ...                 ...
# 24970                                 License                Pass
# 24971                                 Canvass                Pass
# 24972                                 Canvass  Pass w/ Conditions
# 24973                                 Canvass                Pass
# 24974                                 Canvass                Pass
# 24975                                 Canvass  Pass w/ Conditions
# 24976                                 License                Fail
# 24977                                 Canvass  Pass w/ Conditions
# 24978                                 Canvass                Pass
# 24979                                 Canvass                Pass
# 24980                                 Canvass                Pass
# 24981                 Complaint Re-Inspection                Pass
# 24982                                 Canvass                Pass
# 24983                 Complaint Re-Inspection                Pass
# 24984                                 License                Fail
# 24985                               Complaint                Fail
# 24986                                 Canvass                Fail
# 24987                   Canvass Re-Inspection                Pass
# 24988                   License Re-Inspection                Pass
# 24989                                 Canvass                Pass
# 24990                                 Canvass                Fail
# 24991                   Canvass Re-Inspection                Pass
# 24992                                 Canvass                Pass
# 24993                                 Canvass                Fail
# 24994                                 Canvass                Pass
# 24995                                 Canvass                Fail
# 24996                                 Canvass                Pass
# 24997                                 License                Fail
# 24998                 Complaint Re-Inspection                Pass
# 24999                               Complaint  Pass w/ Conditions
#
#                   risk
# 0      Risk 2 (Medium)
# 1        Risk 1 (High)
# 2        Risk 1 (High)
# 3        Risk 1 (High)
# 4         Risk 3 (Low)
# 5        Risk 1 (High)
# 6        Risk 1 (High)
# 7        Risk 1 (High)
# 8        Risk 1 (High)
# 9      Risk 2 (Medium)
# 10       Risk 1 (High)
# 11       Risk 1 (High)
# 12     Risk 2 (Medium)
# 13       Risk 1 (High)
# 14       Risk 1 (High)
# 15     Risk 2 (Medium)
# 16        Risk 3 (Low)
# 17       Risk 1 (High)
# 18     Risk 2 (Medium)
# 19       Risk 1 (High)
# 20       Risk 1 (High)
# 21       Risk 1 (High)
# 22       Risk 1 (High)
# 23       Risk 1 (High)
# 24       Risk 1 (High)
# 25       Risk 1 (High)
# 26     Risk 2 (Medium)
# 27     Risk 2 (Medium)
# 28       Risk 1 (High)
# 29       Risk 1 (High)
# ...                ...
# 24970    Risk 1 (High)
# 24971    Risk 1 (High)
# 24972    Risk 1 (High)
# 24973    Risk 1 (High)
# 24974  Risk 2 (Medium)
# 24975    Risk 1 (High)
# 24976    Risk 1 (High)
# 24977    Risk 1 (High)
# 24978    Risk 1 (High)
# 24979     Risk 3 (Low)
# 24980    Risk 1 (High)
# 24981    Risk 1 (High)
# 24982    Risk 1 (High)
# 24983    Risk 1 (High)
# 24984  Risk 2 (Medium)
# 24985  Risk 2 (Medium)
# 24986  Risk 2 (Medium)
# 24987    Risk 1 (High)
# 24988    Risk 1 (High)
# 24989    Risk 1 (High)
# 24990  Risk 2 (Medium)
# 24991    Risk 1 (High)
# 24992    Risk 1 (High)
# 24993    Risk 1 (High)
# 24994    Risk 1 (High)
# 24995    Risk 1 (High)
# 24996    Risk 1 (High)
# 24997    Risk 1 (High)
# 24998    Risk 1 (High)
# 24999    Risk 1 (High)
#
# [25000 rows x 4 columns]

# %% [markdown]
# Finally, we might want to exclude a column like `location` since we have the separate `latitude` and `longitude` columns. We can delete columns in a DataFrame using Python's built-in `del` statement.

# %%
del dta['location']

# %% [markdown]
# ## Dealing with Types using csv Reader

# %% [markdown]
# We can do everything that we did above by providing options to `pd.read_csv`.
#
# We saw before that `csv` reads everything in as strings, `json` does some type conversion with facility for doing more, and `pandas` does a bit more type conversion but it isn't always what we want. For example, we want the zip codes to stay strings.

# %% [markdown]
# Let's take a look at how to do with pandas `read_csv`. First, we can use the `parse_dates` argument to read in the larger inspections data sample and tell pandas that one of our columns is a date column. We'll also go ahead and make `inspection_id` the index.

# %%
dta = pd.read_csv(
    "data/health_inspection_chi.csv", 
    index_col="inspection_id",
    parse_dates=["inspection_date"]
)

# %% [markdown]
# Next, we want to turn the zip codes into strings. Here, we need to assume that the input (from the file) is a string as opposed to the above.

# %%
import numpy as np


def float_to_zip(zip_code):
    # convert from the string in the file to a float
    try:
        zip_code = float(zip_code)
    except ValueError:  # some of them are empty
        return np.nan
    
    # 0 makes sure to left-pad with zero
    # zip codes have 5 digits
    # .0 means, we don't want anything after the decimal
    # f is for float
    zip_code = "{:05.0f}".format(zip_code)
    return zip_code

# %%
float_to_zip('1234')
# Out:
# '01234'

# %%
float_to_zip('123456')
# Out:
# '123456'

# %% [markdown]
# As another example of defensive programming, we have to make sure that empty strings are handled.

# %%
float_to_zip('')
# Out:
# nan

# %% [markdown]
# We can supply this function to the `converters` argument.

# %%
dta = pd.read_csv(
    "data/health_inspection_chi.csv",
    converters={
        'zip': float_to_zip
    },
)

# %%
dta.head()
# Out:
#                       address                             aka_name     city  \
# 0            2804 N CLARK ST                  Wells Street Popcorn  CHICAGO
# 1         6744 N SHERIDAN RD                        RICE THAI CAFE  CHICAGO
# 2      160-164 E SUPERIOR ST                  GINO'S EAST PIZZERIA  CHICAGO
# 3       5844-5846 N BROADWAY   RAS DASHEN ETHIOPIAN RESTAURANT INC  CHICAGO
# 4  2352-2358 N MILWAUKEE AVE                             EAST ROOM  CHICAGO
#
#                               dba_name facility_type          inspection_date  \
# 0                 Wells Street Popcorn    Restaurant  2010-02-01T00:00:00.000
# 1                       RICE THAI CAFE    Restaurant  2015-08-21T00:00:00.000
# 2                 GINO'S EAST PIZZERIA    Restaurant  2015-07-28T00:00:00.000
# 3  RAS DASHEN ETHIOPIAN RESTAURANT INC    Restaurant  2017-01-04T00:00:00.000
# 4                            EAST ROOM        Liquor  2013-11-18T00:00:00.000
#
#    inspection_id                         inspection_type   latitude  \
# 0          68091                                 Canvass  41.932921
# 1        1482935                   Canvass Re-Inspection  42.004881
# 2        1447916  Suspected Food Poisoning Re-inspection  41.895863
# 3        1978933                                 Canvass  41.988326
# 4        1375515                   License Re-Inspection  41.923873
#
#     license_                                           location  longitude  \
# 0  1954774.0  {'type': 'Point', 'coordinates': [-87.64515454... -87.645155
# 1  2354674.0  {'type': 'Point', 'coordinates': [-87.66101071... -87.661011
# 2  1697132.0  {'type': 'Point', 'coordinates': [-87.62325304... -87.623253
# 3  1122395.0  {'type': 'Point', 'coordinates': [-87.66036036... -87.660360
# 4  2263696.0  {'type': 'Point', 'coordinates': [-87.69916285... -87.699163
#
#   results             risk state  \
# 0    Pass  Risk 2 (Medium)    IL
# 1    Pass    Risk 1 (High)    IL
# 2    Pass    Risk 1 (High)    IL
# 3    Fail    Risk 1 (High)    IL
# 4    Pass     Risk 3 (Low)    IL
#
#                                           violations    zip
# 0                                                NaN  60657
# 1  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60626
# 2  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60611
# 3  16. FOOD PROTECTED DURING STORAGE, PREPARATION...  60660
# 4                                                NaN  60647

# %% [markdown]
# To exclude location, we can take advantage of the fact that the `usecols` argument accepts a function to exclude `location`.

# %%
dta = pd.read_csv(
    "data/health_inspection_chi.csv",
    usecols=lambda col: col != 'location'
)

# %% [markdown]
# Here we are using a **lambda function** that returns `False` for the location parameter. Lambda functions are what are known as anonymous functions, because they don't have a name. This kind of thing is precisely their intended use.
#
# Here we use a function `lambda x: x` to map the identity function over a list.

# %%
list(map(lambda x: x, [1, 2, 3]))
# Out:
# [1, 2, 3]

# %% [markdown]
# Finally, in a few cases we may want to take advantage of the pandas native `categorical` type. We can use the `dtype` argument for this, passing a dictionary of type mappings.

# %%
dta = pd.read_csv(
    "data/health_inspection_chi.csv",
    dtype={
        'results': 'category',
        'risk': 'category',
        'inspection_type': 'category',
        'facility_type': 'category'
    }
)

# %%
dta.risk.head()
# Out:
# 0    Risk 2 (Medium)
# 1      Risk 1 (High)
# 2      Risk 1 (High)
# 3      Risk 1 (High)
# 4       Risk 3 (Low)
# Name: risk, dtype: category
# Categories (4, object): [All, Risk 1 (High), Risk 2 (Medium), Risk 3 (Low)]

# %% [markdown]
# ## Exercise
#
# Put all of the above `read_csv` options together in a single call to `read_csv`.

# %%
# Type your solution here

# %%
# %load solutions/pandas_read_csv.py
import numpy as np
import pandas as pd


def float_to_zip(zip_code):
    # convert from the string in the file to a float
    try:
        zip_code = float(zip_code)
    except ValueError:  # some of them are empty
        return np.nan

    # 0 makes sure to left-pad with zero
    # zip codes have 5 digits
    # .0 means, we don't want anything after the decimal
    # f is for float
    zip_code = "{:05.0f}".format(zip_code)
    return zip_code


dta = pd.read_csv(
    "data/health_inspection_chi.csv",
    index_col='inspection_id',
    parse_dates=['inspection_date'],
    converters={
        'zip': float_to_zip
    },
    usecols=lambda col: col != 'location',
    dtype={
        'results': 'category',
        'risk': 'category',
        'inspection_type': 'category',
        'facility_type': 'category'
    }
)


assert float_to_zip('1234')
assert float_to_zip('123456')
assert np.isnan(float_to_zip(''))

# %% [markdown]
# ## String Cleaning

# %% [markdown]
# Ok, let's start to dig into the data a little bit more. One of the things we're going to be really interested in exploring is the free text of the violations field.

# %% [markdown]
# The first thing to notice is that the violations field has null values in it.

# %%
dta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 17 columns):
# address            25000 non-null object
# aka_name           24731 non-null object
# city               24978 non-null object
# dba_name           25000 non-null object
# facility_type      24565 non-null category
# inspection_date    25000 non-null object
# inspection_id      25000 non-null int64
# inspection_type    25000 non-null category
# latitude           24822 non-null float64
# license_           24999 non-null float64
# location           24822 non-null object
# longitude          24822 non-null float64
# results            25000 non-null category
# risk               24991 non-null category
# state              24995 non-null object
# violations         19538 non-null object
# zip                24991 non-null float64
# dtypes: category(4), float64(4), int64(1), object(8)
# memory usage: 2.6+ MB

# %% [markdown]
# We may want to ask ourselves if these values are missing at random or if there is some reason there's no written violation field.

# %%
dta.loc[dta.violations.isnull()].head()
# Out:
#                           address              aka_name     city  \
# 0                2804 N CLARK ST   Wells Street Popcorn  CHICAGO
# 4      2352-2358 N MILWAUKEE AVE              EAST ROOM  CHICAGO
# 9             2506 N LARAMIE AVE      Cuernavaca Bakery  CHICAGO
# 10  131 N CLINTON ST BLDG BOOTH26   PAPPARDELLE'S PASTA  CHICAGO
# 13               200 W MONROE ST     JERSEY MIKE'S SUBS  CHICAGO
#
#                 dba_name facility_type          inspection_date  \
# 0   Wells Street Popcorn    Restaurant  2010-02-01T00:00:00.000
# 4              EAST ROOM        Liquor  2013-11-18T00:00:00.000
# 9      Cuernavaca Bakery        Bakery  2017-12-21T00:00:00.000
# 10   PAPPARDELLE'S PASTA    Restaurant  2011-02-23T00:00:00.000
# 13    JERSEY MIKE'S SUBS    Restaurant  2016-03-28T00:00:00.000
#
#     inspection_id        inspection_type   latitude   license_  \
# 0           68091                Canvass  41.932921  1954774.0
# 4         1375515  License Re-Inspection  41.923873  2263696.0
# 9         2129593                Canvass  41.926211  2192872.0
# 10         565226                Canvass  41.884188  2022121.0
# 13        1684292  Canvass Re-Inspection  41.880769  2398227.0
#
#                                              location  longitude  \
# 0   {'type': 'Point', 'coordinates': [-87.64515454... -87.645155
# 4   {'type': 'Point', 'coordinates': [-87.69916285... -87.699163
# 9   {'type': 'Point', 'coordinates': [-87.75637041... -87.756370
# 10  {'type': 'Point', 'coordinates': [-87.64111966... -87.641120
# 13  {'type': 'Point', 'coordinates': [-87.63387497... -87.633875
#
#             results             risk state violations      zip
# 0              Pass  Risk 2 (Medium)    IL        NaN  60657.0
# 4              Pass     Risk 3 (Low)    IL        NaN  60647.0
# 9   Out of Business  Risk 2 (Medium)    IL        NaN  60639.0
# 10  Out of Business    Risk 1 (High)    IL        NaN  60661.0
# 13             Pass    Risk 1 (High)    IL        NaN  60606.0

# %% [markdown]
# It looks like we're ok. The next thing to notice is that the violation field actually has a lot of violations in the same field for the same visit.

# %%
with pd.option_context("display.max_colwidth", 500):
    print(dta.violations.head())
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# 1    32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED - Comments: BROKEN RUBBER GASKET INSIDE THE DOORS OF DISPLAY FRONT COOLER.EXCESS GRAY TAPE HOLDING THE BROKEN RUBBER GASKET WITH DEBRIS AND BLACK SUBSTANCE ON IT,INSTRUCTED TO REPLACE. NEWSPAPER AND CARDBOARDS ON SHELVES THROUGHOUT THE PREMISES(FIRST AND SECOND FLOOR)CARD BOARDS AREA GREASY AND DUST BUILD-UP,INSTRUCTED TO REMOVE,SURFACE MUST BE SMOOTH,CLEANABLE AND NON-ABSORBENT MATERIAL.    | 33. FOOD AND N...
# 2    32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED - Comments:  MUST INSTALL A SPLASH GUARD BETWEEN THE ICE BIN AND THE EXPOSED HAND SINK AND THE EXPOSED HAND SINK AND THE DRAIN BOARD FOR CLEAN GLASSES BEHIND THE 1ST FLOOR BAR. WORN OUT CAULK WITH BLACK MOLDY LIKE SUBSTANCE ON THE 2ND FLOOR 2 COMPARTMENT SINK, AND 3 COMPARTMENT SINK. MUST RE CAULK AND MAINTAIN. RUSTED WIRE RACK SHELVINGS INSIDE THE WALK IN COOLER ON THE 2ND FLOOR. MUST REMOVE RUST AND MAINTA...
# 3    16. FOOD PROTECTED DURING STORAGE, PREPARATION, DISPLAY, SERVICE AND TRANSPORTATION - Comments: FOOD(ICE) NOT PROTECTED DURING STORAGE.WE OBSERVED INTERIOR OF ICE MACHINE WATER RESERVOIR WITH EXCESS BLACK SLIME SUBSTANCE DRIPPING INTO WATER WHERE ICE IS MADE.INSTRUCTED TO CLEAN,SANITIZE AND MAINTAINED SAID UNIT. SERIOUS VIOLATION:7-38-005(A) | 32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED - Comments: NO VENTILATION OR UNDER THE HOOD PROVIDED AT ONE BURN...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# Name: violations, dtype: object

# %% [markdown]
# Let's split these out to make a longer DataFrame where each violation is a single row. Pandas provides a nice way to munge string data through the `str` accessor on string columns.
#
# ```python
# dta.violations.str.<TAB>
# ```

# %% [markdown]
# ## Exercise
#
# Let's see how many violations we have per visit. What does the distribution of violations look like? Explore the methods on the `str` accessor and, perhaps, the `quantile` method.

# %%
# Type your solution here

# %%
# %load solutions/violation_distribution.py
import numpy as np
import pandas as pd


def float_to_zip(zip_code):
    # convert from the string in the file to a float
    try:
        zip_code = float(zip_code)
    except ValueError:  # some of them are empty
        return np.nan

    # 0 makes sure to left-pad with zero
    # zip codes have 5 digits
    # .0 means, we don't want anything after the decimal
    # f is for float
    zip_code = "{:05.0f}".format(zip_code)
    return zip_code


dta = pd.read_csv(
    "data/health_inspection_chi.csv",
    index_col='inspection_id',
    parse_dates=['inspection_date'],
    converters={
        'zip': float_to_zip
    },
    usecols=lambda col: col != 'location',
    dtype={
        'results': 'category',
        'risk': 'category',
        'inspection_type': 'category',
        'facility_type': 'category'
    }
)


quantiles = [0, .05, .25, .50, .75, .95, 1.00]
(dta.violations.str.count("\|") + 1).quantile(quantiles)

# %%
quantiles = [0, .05, .25, .50, .75, .95, 1.00]
(dta.violations.str.count("\|") + 1).quantile(quantiles)
# Out:
# 0.00     1.0
# 0.05     1.0
# 0.25     2.0
# 0.50     3.0
# 0.75     5.0
# 0.95     9.0
# 1.00    23.0
# Name: violations, dtype: float64

# %%
(dta.violations.str.count("\|") + 1)
# Out:
# 0         NaN
# 1         6.0
# 2         5.0
# 3         6.0
# 4         NaN
# 5         2.0
# 6         4.0
# 7         2.0
# 8         2.0
# 9         NaN
# 10        NaN
# 11        6.0
# 12        1.0
# 13        NaN
# 14        NaN
# 15        1.0
# 16        7.0
# 17        NaN
# 18        3.0
# 19        NaN
# 20        4.0
# 21        2.0
# 22        NaN
# 23        1.0
# 24        6.0
# 25        1.0
# 26       13.0
# 27        NaN
# 28        2.0
# 29        6.0
#          ...
# 24970     3.0
# 24971     3.0
# 24972     3.0
# 24973     1.0
# 24974     3.0
# 24975     2.0
# 24976     8.0
# 24977     9.0
# 24978     5.0
# 24979     3.0
# 24980     2.0
# 24981     8.0
# 24982     3.0
# 24983     NaN
# 24984     5.0
# 24985     9.0
# 24986     2.0
# 24987     2.0
# 24988     2.0
# 24989     2.0
# 24990     6.0
# 24991     NaN
# 24992     2.0
# 24993     6.0
# 24994     3.0
# 24995     6.0
# 24996     5.0
# 24997     1.0
# 24998     9.0
# 24999     5.0
# Name: violations, Length: 25000, dtype: float64

# %% [markdown]
# Ok, we have a manageable number of violations. Let's split the violations and then turn them into a long DataFrame with a single row for each violation within each visit.

# %%
dta = dta.set_index('inspection_id')
violations = dta.violations.str.split("\|", expand=True)
violations.head()
# Out:
#                                                               0   \
# inspection_id
# 68091                                                        NaN
# 1482935        32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# 1447916        32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# 1978933        16. FOOD PROTECTED DURING STORAGE, PREPARATION...
# 1375515                                                      NaN
#
#                                                               1   \
# inspection_id
# 68091                                                        NaN
# 1482935         33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENS...
# 1447916         33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENS...
# 1978933         32. FOOD AND NON-FOOD CONTACT SURFACES PROPER...
# 1375515                                                      NaN
#
#                                                               2   \
# inspection_id
# 68091                                                        NaN
# 1482935         34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GO...
# 1447916         34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GO...
# 1978933         33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENS...
# 1375515                                                      NaN
#
#                                                               3   \
# inspection_id
# 68091                                                        NaN
# 1482935         35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONST...
# 1447916         35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONST...
# 1978933         34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GO...
# 1375515                                                      NaN
#
#                                                               4   \
# inspection_id
# 68091                                                        NaN
# 1482935         36. LIGHTING: REQUIRED MINIMUM FOOT-CANDLES O...
# 1447916         36. LIGHTING: REQUIRED MINIMUM FOOT-CANDLES O...
# 1978933         35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONST...
# 1375515                                                      NaN
#
#                                                               5     6     7   \
# inspection_id
# 68091                                                        NaN   NaN   NaN
# 1482935         43. FOOD (ICE) DISPENSING UTENSILS, WASH CLOT...  None  None
# 1447916                                                     None  None  None
# 1978933         38. VENTILATION: ROOMS AND EQUIPMENT VENTED A...  None  None
# 1375515                                                      NaN   NaN   NaN
#
#                  8     9   ...     13    14    15    16    17    18    19  \
# inspection_id              ...
# 68091           NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1482935        None  None  ...   None  None  None  None  None  None  None
# 1447916        None  None  ...   None  None  None  None  None  None  None
# 1978933        None  None  ...   None  None  None  None  None  None  None
# 1375515         NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                  20    21    22
# inspection_id
# 68091           NaN   NaN   NaN
# 1482935        None  None  None
# 1447916        None  None  None
# 1978933        None  None  None
# 1375515         NaN   NaN   NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# When we `unstack` the DataFrame, we're left with what's called a `MultiIndex`. This index has two *levels* now. One is the original `inspection_id`. The other is the, rather meaningless, column names.

# %%
violations.unstack().head()
# Out:
#    inspection_id
# 0  68091                                                          NaN
#    1482935          32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
#    1447916          32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
#    1978933          16. FOOD PROTECTED DURING STORAGE, PREPARATION...
#    1375515                                                        NaN
# dtype: object

# %% [markdown]
# Let's get rid of the empty rows first.

# %%
violations = violations.unstack().dropna()

# %%
violations.head()
# Out:
#    inspection_id
# 0  1482935          32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
#    1447916          32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
#    1978933          16. FOOD PROTECTED DURING STORAGE, PREPARATION...
#    1434800          33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...
#    1106632          32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# dtype: object

# %% [markdown]
# Now we can drop the column name level, which we don't need.

# %%
violations.reset_index(level=0, drop=True, inplace=True)

# %%
violations.head()
# Out:
# inspection_id
# 1482935    32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# 1447916    32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# 1978933    16. FOOD PROTECTED DURING STORAGE, PREPARATION...
# 1434800    33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...
# 1106632    32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# dtype: object

# %% [markdown]
# One last cleaning step may be helpful here. When we split on the pipe ('`|`'), we likely kept some surrounding whitespace. We can remove that.

# %%
violations.str.startswith(" ").any()
# Out:
# True

# %%
violations.str.strip().head()
# Out:
# inspection_id
# 1482935    32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# 1447916    32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# 1978933    16. FOOD PROTECTED DURING STORAGE, PREPARATION...
# 1434800    33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...
# 1106632    32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# dtype: object

# %%
violations = violations.str.strip()

# %%
((violations.str.startswith(" ").any()) | 
 (violations.str.endswith(" ").any()))

# %% [markdown]
# Later, we'll see how to combine these violations back with our original data to do some analysis.

# %% [markdown]
# ## Working with Dates and Categoricals

# %% [markdown]
# Above, we used the `str` accessor on the DataFrame. This isn't the only convenient accessor that pandas provides. There is also the `dt` accessor for datetime types and the `cat` accessor for categorical types.

# %% [markdown]
# ```python
# dta.inspection_date.dt.<TAB>
# ```

# %%
dta.inspection_date.head()

# %%
dta.inspection_date.dt.month.head()

# %% [markdown]
# Now, let's take a look at the categorical types.

# %% [markdown]
# ```python
# dta.risk.cat.<TAB>
# ```

# %%
dta.risk.head()

# %%
dta.risk.cat.codes.head()
